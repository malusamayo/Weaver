# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from knowtest.server.Capability import Capability

# %%
c = Capability()
# Out:
# Path:  ../output OS Path:  /Users/rishabhrustogi/Desktop/knowtest/notebooks
# Cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/root
# stateSaveDirectory: ../output/savedStates/
# maxStates: 100
# 1. removing state_2023-03-04_14-11-23-473346.json
# 1. removing state_2023-03-04_14-12-53-915456.json
# 1. removing state_2023-03-04_14-12-31-760189.json
# 1. removing state_2023-03-04_14-11-18-782392.json
# 1. removing state_2023-03-04_14-12-55-288396.json
# 1. removing state_2023-03-04_14-12-36-312511.json
# 1. removing state_2023-03-04_14-12-27-113217.json
# 1. removing state_2023-03-04_14-12-37-320528.json
# Setting root node:  Hate speech
# Starting server on port:  3001

# %%
c.change_topic("Hotel Reviews")
# Out:
# Path:  ../output OS Path:  /Users/rishabhrustogi/Desktop/knowtest/notebooks
# Cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Hotel_Reviews
# stateSaveDirectory: ../output/savedStates/
# maxStates: 100
# 1. removing state_2023-03-04_14-20-57-349936.json
# 1. removing state_2023-03-04_14-20-50-258299.json
# 1. removing state_2023-03-04_14-20-37-617353.json
# 1. removing state_2023-03-04_14-20-36-686407.json
# Setting root node:  Hotel reviews
# making copy of ../output/Hotel_Reviews.json to ../output/savedStates/state_2023-03-04_14-21-26-040032.json
# self.stack: ['state_2023-03-04_14-21-26-040032.json']
# Refresh suggestion path: Getting node path for:  8306c043-3176-4363-835d-576f648fd83e
#  [{'topic': 'Hotel reviews', 'relation': ''}]
# Refresh suggestion existing_children:  []
# Creating cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Hotel_Reviews/hotel reviews
# making copy of ../output/Hotel_Reviews.json to ../output/savedStates/state_2023-03-04_14-21-35-713666.json
# self.stack: ['state_2023-03-04_14-21-26-040032.json', 'state_2023-03-04_14-21-35-713666.json']
# Refresh suggestion path: Getting node path for:  87e2d35f-98e5-47d5-b23b-ed2718b0ec20
#  [{'topic': 'Hotel reviews', 'relation': ''}, {'topic': 'Lobby', 'relation': 'DONETO'}]
# Refresh suggestion existing_children:  []
# Creating cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Hotel_Reviews/lobby
# Exception in thread Thread-81 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 714090 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x2d1eba1d0 state=finished raised RateLimitError>]
# Exception in thread Thread-90 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 833140 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x2e6705d50 state=finished raised RateLimitError>]
# Exception in thread Thread-104 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 476060 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x2d4642450 state=finished raised RateLimitError>]
# Exception in thread Thread-105 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 515710 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x2e67053d0 state=finished raised RateLimitError>]
# Exception in thread Thread-92 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 555390 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x30bec1510 state=finished raised RateLimitError>]
# Exception in thread Thread-88 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 436370 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x30bec2210 state=finished raised RateLimitError>]
# Exception in thread Thread-91 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 833090 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x305a86750 state=finished raised RateLimitError>]
# Exception in thread Thread-97 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 714120 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x305a84990 state=finished raised RateLimitError>]
# Exception in thread Thread-89 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 872770 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x305a85f90 state=finished raised RateLimitError>]
# Exception in thread Thread-98 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 912460 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x2cb296650 state=finished raised RateLimitError>]
# Exception in thread Thread-102 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 555470 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x2f911b510 state=finished raised RateLimitError>]
# Exception in thread Thread-100 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 952140 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x2f9118c50 state=finished raised RateLimitError>]
# Exception in thread Thread-85 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 753790 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
# ...
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x2d216a690 state=finished raised RateLimitError>]
# Exception in thread Thread-119 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 436390 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x2d216a190 state=finished raised RateLimitError>]
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 74, in __call__
#     response = self._get_completion(prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knmodel.py", line 63, in _get_completion
#     return openai.Completion.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 226, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 619, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/openai/api_requestor.py", line 679, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-text-davinci-003 in organization org-WOVGhnT9SqH4gDorVZKKiZ3b on tokens per min. Limit: 250000 / min. Current: 317350 / min. Contact support@openai.com if you continue to have issues.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/uvicorn/protocols/http/httptools_impl.py", line 419, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 78, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/fastapi/applications.py", line 271, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/applications.py", line 118, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/middleware/cors.py", line 92, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/middleware/cors.py", line 147, in simple_response
#     await self.app(scope, receive, send)
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/fastapi/middleware/asyncexitstack.py", line 21, in __call__
#     raise e
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/fastapi/middleware/asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/routing.py", line 706, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/fastapi/routing.py", line 237, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/fastapi/routing.py", line 165, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/anyio/to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/server/Server.py", line 61, in set_open
#     self.t.set_open(node_id, bool)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/server/Tree.py", line 130, in set_open
#     self.refresh_suggestions(node_id)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/server/Tree.py", line 227, in refresh_suggestions
#     suggestions = self.kg.expand_node(topic=self.nodes[node_id].name.lower(), path=path, existing_children=existing_children)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 143, in expand_node
#     self.extend_node_all_relation(topic)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 94, in extend_node_all_relation
#     self.extend_node(topic, relation)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 69, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 91, in query_topics
#     response = self.model(prompt)
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 379, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/site-packages/tenacity/__init__.py", line 326, in iter
#     raise retry_exc from fut.exception()
# tenacity.RetryError: RetryError[<Future at 0x2d0dd2450 state=finished raised RateLimitError>]
# making copy of ../output/Hotel_Reviews.json to ../output/savedStates/state_2023-03-04_14-23-36-709476.jsonGetting node path for:  244ef97e-7269-40b9-b54e-7e318bfb561e
#
# self.stack: ['state_2023-03-04_14-21-26-040032.json', 'state_2023-03-04_14-21-35-713666.json', 'state_2023-03-04_14-22-19-250790.json', 'state_2023-03-04_14-22-20-226130.json', 'state_2023-03-04_14-22-54-487900.json', 'state_2023-03-04_14-23-36-709476.json']
# making copy of ../output/Hotel_Reviews.json to ../output/savedStates/state_2023-03-04_14-23-37-785278.jsonGetting node path for:  244ef97e-7269-40b9-b54e-7e318bfb561e
#
# self.stack: ['state_2023-03-04_14-21-26-040032.json', 'state_2023-03-04_14-21-35-713666.json', 'state_2023-03-04_14-22-19-250790.json', 'state_2023-03-04_14-22-20-226130.json', 'state_2023-03-04_14-22-54-487900.json', 'state_2023-03-04_14-23-36-709476.json', 'state_2023-03-04_14-23-37-785278.json']
# Going to previous state
# self.stack: ['state_2023-03-04_14-21-26-040032.json', 'state_2023-03-04_14-21-35-713666.json', 'state_2023-03-04_14-22-19-250790.json', 'state_2023-03-04_14-22-20-226130.json', 'state_2023-03-04_14-22-54-487900.json', 'state_2023-03-04_14-23-36-709476.json', 'state_2023-03-04_14-23-37-785278.json']
# Setting root node:  Hotel reviews
# Stack: ['state_2023-03-04_14-21-26-040032.json', 'state_2023-03-04_14-21-35-713666.json', 'state_2023-03-04_14-22-19-250790.json', 'state_2023-03-04_14-22-20-226130.json', 'state_2023-03-04_14-22-54-487900.json', 'state_2023-03-04_14-23-36-709476.json']
# 3. removing state_2023-03-04_14-23-37-785278.json
# making copy of ../output/Hotel_Reviews.json to ../output/savedStates/state_2023-03-04_14-23-45-052590.jsonGetting node path for:  244ef97e-7269-40b9-b54e-7e318bfb561e
#
# self.stack: ['state_2023-03-04_14-21-26-040032.json', 'state_2023-03-04_14-21-35-713666.json', 'state_2023-03-04_14-22-19-250790.json', 'state_2023-03-04_14-22-20-226130.json', 'state_2023-03-04_14-22-54-487900.json', 'state_2023-03-04_14-23-36-709476.json', 'state_2023-03-04_14-23-45-052590.json']

# %% [markdown]
# |      Topics and Relations      |   |             Tooltip            |
# |:------------------------------:|:-:|:------------------------------:|
# |      <img src="data:image/png;base64,..." alt="Image" width="20" height="17"> Unhighlighted Topic     |   |       <img src="data:image/png;base64,..." alt="Image" width="18" height="19"> Highlight a Topic      |
# |       <img src="data:image/png;base64,..." alt="Image" width="19" height="18"> Highlighted Topic      |   |      <img src="data:image/png;base64,..." alt="Image" width="19" height="16"> Unhighlight a Topic     |
# |        <img src="data:image/png;base64,..." alt="Image" width="16" height="17"> Expanded topic        |   |      <img src="data:image/png;base64,..." alt="Image" width="17" height="20"> Refresh Suggestions     |
# |           <img src="data:image/png;base64,..." alt="Image" width="65" height="25"> Relation           |   | <img src="data:image/png;base64,..." alt="Image" width="18" height="20"> Edit Topic Name and Relation |
# | <img src="data:image/png;base64,..." alt="Image" width="140" height="22"> Relation and Topic wrt Parent |   |   <img src="data:image/png;base64,..." alt="Image" width="23" height="21"> Create new Topic Manually  |
# |      <img src="data:image/png;base64,..." alt="Image" width="108" height="46"> Filter by Relation      |   |        <img src="data:image/png;base64,..." alt="Image" width="16" height="17"> Delete a Topic        |

# %%
c.get_html_file()

# %%
c.get_js_file()

# %%
c.get_css_file()
