# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from knowtest.server.Capability import Capability

# %%
c = Capability()
# Out:
# ../output/hate_speech
# Path:  ../output OS Path:  /Users/rishabhrustogi/Desktop/knowtest/notebooks
# Initializing wordnet
# Cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/hate_speech
# stateSaveDirectory: ../output/savedStates/
# maxStates: 100
# Setting root node:  Hate speech
# Starting server on port:  3001

# %%
c.change_topic("Cab Review")
# Out:
# ../output/Cab_Review
# Running Knowledge Base Construction
# Cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Cab_Review
# Cab Review TYPEOF ['driver', 'limo', 'safety', 'flexibility', 'cost', 'attitude', 'cleanliness', 'courtesy', 'navigation', 'timeliness', 'knowledge', 'reliability', 'communication', 'airport', 'professionalism', 'quality', 'chauffeur', 'taxi', 'luxury', 'ride-share', 'comfort']
# Cab Review PARTOF ['safety', 'check-out', 'amenity', 'parking', 'noise', 'wifi', 'cleanliness', 'price', 'check-in', 'spa', 'child-friendly', 'gym', 'pool', 'location', 'entertainment', 'drink', 'pet-friendly', 'staff', 'rating', 'food', 'comfort']
# Cab Review HASPROPERTY ['trustworthy', 'fast', 'reliable', 'helpful', 'comfortable', 'easy', 'courteous', 'timely', 'professional', 'relaxing', 'affordable', 'efficient', 'convenient', 'quality', 'accurate', 'safe', 'secure', 'dependable', 'friendly', 'knowledgeable']
# Cab Review USEDFOR ['real-time tracking', 'taxi booking', 'driver rating', 'destination suggestion', 'safety monitoring', 'navigation assistance', 'payment processing', 'ride hailing', 'vehicle tracking', 'airport transfer', 'driver management', 'driver incentive', 'trip scheduling', 'trip tracking', 'route optimization', 'commuting', 'route planning', 'ride sharing', 'customer feedback', 'fleet management']
# Cab Review ATLOCATION ['hotel', 'shopping mall', 'concert hall', 'library', 'military base', 'office building', 'beach', 'supermarket', 'school', 'bar', 'church', 'movie theater', 'hospital', 'gym', 'airport', 'bus station', 'train station', 'park', 'sport stadium', 'university', 'restaurant']
# Cab Review CAUSES ['unsafe', 'inconsistent', 'unreliable service', 'unreliable vehicle', 'time-consuming', 'unscrupulous operator', 'unreliable pricing', 'unreliable customer service', 'lack of accountability', 'uncertainty', 'inaccurate', 'costly', 'unreliable payment method', 'lack of quality control', 'unreliable driver', 'unprofessional', 'inconvenient', 'unregulated', 'risky', 'unreliable']
# Cab Review MOTIVATEDBY ['convenience', 'safety', 'satisfaction', 'peace-of-mind', 'cost', 'customer-service', 'recommendation', 'trust', 'reliability', 'communication', 'selection', 'accessibility', 'security', 'time-saving', 'quality', 'accountability', 'ease', 'reassurance', 'feedback', 'comfort']
# Cab Review OBSTRUCTEDBY ['unsafe', 'unlawful', 'unresponsive', 'inconsistent', 'unsatisfactory', 'unacceptable', 'unreliable-drivers', 'poorly-rated', 'inadequate', 'unfair', 'inaccurate', 'inefficient', 'unhelpful', 'unreliable-service', 'unprofessional', 'unethical', 'expensive', 'unfriendly', 'unsanitary', 'unreliable', 'unreliable-vehicles']
# Cab Review MANNEROF ['research', 'ass', 'critique', 'analyze', 'examine', 'question', 'inspect', 'consider', 'evaluate', 'listen', 'investigate', 'interrogate', 'compile', 'study', 'review', 'discus', 'observe', 'compare', 'debate']
# Cab Review LOCATEDNEAR ['hotel', 'police station', 'shopping mall', 'library', 'subway', 'fire station', 'school', 'café', 'bar', 'church', 'hospital', 'grocery', 'airport', 'train', 'park', 'theater', 'bank', 'taxi', 'bus', 'restaurant', 'gas station']
# Cab Review CAPABLEOF ['booking', 'analyzing', 'reporting', 'pricing', 'communicating', 'reviewing', 'simplifying', 'integrating', 'mapping', 'tracking', 'recommending', 'optimizing', 'navigating', 'searching', 'rating', 'scheduling', 'calculating', 'customizing', 'comparing', 'organizing', 'monitoring']
# Cab Review HASSUBEVENT ['fare', 'safety', 'accuracy', 'route', 'cleanliness', 'pickup', 'navigation', 'complaint', 'knowledge', 'hospitality', 'dropoff', 'speed', 'payment', 'communication', 'review', 'refund', 'suggestion', 'rating', 'feedback', 'comfort', 'booking']
# Cab Review HASPREREQUISITE ['reflect', 'order', 'research', 'remember', 'rate', 'outfit', 'share', 'eat', 'greet', 'chat', 'transportation', 'pay', 'location', 'leave', 'discus', 'arrive', 'drink', 'plan', 'book', 'comment']
# Cab Review DESIRES ['trustworthy', 'affordability', 'reliable', 'convenience', 'safety', 'friendliness', 'punctuality', 'responsiveness', 'cleanliness', 'accommodating', 'variety', 'reliability', 'courteousness', 'flexible', 'efficiency', 'professionalism', 'quality', 'hassle-free', 'comfort', 'secure', 'knowledgeable']
# Cab Review CREATEDBY ['via', 'mytaxi', 'flywheel', 'uber', 'cabso', 'cabify', 'taxify', 'hailo', 'cabcorner', 'curb', 'fasten', 'zemcar', 'migo', 'lyft', 'a2b', 'kabbee', 'wingz', 'easy taxi', 'arro', 'taxistartup', 'gett']
# Cab Review SYMBOLOF ['driver', 'clock', 'dollar sign', 'credit card', 'app', 'navigation', 'person', 'ride', 'gps', 'five star', 'payment', 'review', 'check mark', 'map', 'phone', 'profile', 'rating', 'taxi', 'street sign', 'feedback', 'car']
# Cab Review CAUSESDESIRE ['affordability', 'convenience', 'safety', 'flexibility', 'availability', 'punctuality', 'accuracy', 'cleanliness', 'accommodation', 'knowledge', 'reliability', 'speed', 'communication', 'courteousness', 'efficiency', 'professionalism', 'security', 'quality', 'ease', 'value', 'comfort']
# Cab Review MADEOF ['airport transfer', 'luxury vehicle', 'minivan', 'wheelchair accessible vehicle', 'suv', 'uber', 'ride-hailing', 'limousine', 'car hire', 'vehicle rental', 'ridesharing', 'automobile', 'shuttle service', 'lyft', 'van', 'taxi', 'motorcycle', 'bus', 'car']
# Cab Review RECEIVESACTION ['rate', 'message', 'share', 'report', 'edit', 'search', 'update', 'filter', 'survey', 'follow', 'pay', 'save', 'review', 'track', 'map', 'compare', 'cancel', 'book', 'comment']
# Cab Review DESIREDBY ['hotel', 'driver', 'airport authority', 'tourist', 'ride-sharing apps', 'traveler', 'airline company', 'online platform', 'government agency', 'taxi apps', 'marketer', 'customer', 'bar', 'tourism board', 'cab company', 'analyst', 'local business', 'event planner', 'restaurant', 'tour operator', 'business']
# Cab Review CREATES ['opinion', 'solution', 'experience', 'observation', 'analysis', 'compliment', 'recommendation', 'question', 'thought', 'dislike', 'complaint', 'criticism', 'review', 'like', 'insight', 'suggestion', 'rating', 'comment', 'idea', 'feedback', 'concern']
# Cab Review CAUSEDBY ['driver', 'experience', 'safety', 'weather', 'cost', 'route', 'traffic', 'distance', 'cleanliness', 'customer', 'service', 'time', 'ride', 'vehicle', 'payment', 'destination', 'location', 'rating', 'scheduling', 'comfort']
# Cab Review DONEBY ['taxi company', 'driver', 'local government', 'online review', 'mobile apps', 'traffic manager', 'medium outlet', 'transportation agency', 'gps provider', 'car manufacturer', 'parking service', 'customer', 'regulatory body', 'car mechanic', 'car rental company', 'ride-sharing service', 'insurance company', 'bank', 'local police', 'payment processor']
# Cab Review DESIRECAUSEDBY ['affordability', 'convenience', 'safety', 'flexibility', 'friendliness', 'punctuality', 'reputation', 'cleanliness', 'variety', 'trustworthiness', 'reliability', 'speed', 'discount', 'promotion', 'security', 'quality', 'ease', 'value', 'comfort']
# Cab Review DONETO ['tourist attraction', 'hotel', 'shopping mall', 'taxi service', 'amusement park', 'school', 'bar', 'movie theater', 'hospital', 'salon', 'spa', 'museum', 'gym', 'club', 'car rental company', 'airport', 'grocery store', 'train station', 'park', 'cafe', 'restaurant']
# Cab Review RELATEDTO ['comfort level', 'real-time tracking', 'customer rating', 'driver rating', 'trip cost', 'scheduled booking', 'drop-off location', 'customer service', 'ride-hailing', 'trip distance', 'timeliness', 'driver review', 'pick-up location', 'route optimization', 'vehicle maintenance', 'payment method', 'insurance coverage', 'vehicle type', 'vehicle cleanliness', 'driver safety', 'cab availability']
# Knowledge base stored at ../output/Cab_Review
# Path:  ../output OS Path:  /Users/rishabhrustogi/Desktop/knowtest/notebooks
# Initializing wordnet
# Cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Cab_Review
# stateSaveDirectory: ../output/savedStates/
# maxStates: 100
# Setting root node:  Cab Review
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  TYPEOF
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  CREATEDBY
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  SYMBOLOF
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  CAUSESDESIRE
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  MADEOF
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CAUSEDBY
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  DESIRECAUSEDBY
# relation:  DESIRECAUSEDBY
# relation:  DESIRECAUSEDBY
# relation:  DESIRECAUSEDBY
# relation:  DESIRECAUSEDBY
# relation:  DESIRECAUSEDBY
# relation:  DESIRECAUSEDBY
# relation:  DESIRECAUSEDBY
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# Exception in thread Thread-46 (extend_node):
# Traceback (most recent call last):
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rishabhrustogi/miniforge3/envs/jupyter-react-widget/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/knbase.py", line 74, in extend_node
#     new_topics = self.prompter.query_topics(topic, relation, known_topics=known_topics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/prompt.py", line 103, in query_topics
#     self.cache.cache_queries(topic, relation, cached_topics + topic_list)
#   File "/Users/rishabhrustogi/Desktop/knowtest/knowtest/knowledge/cache.py", line 24, in cache_queries
#     os.makedirs(topic_dir)
#   File "<frozen os>", line 225, in makedirs
# FileExistsError: [Errno 17] File exists: '/Users/rishabhrustogi/Desktop/knowtest/query_cache/Cab_Review/courteousness'
# Creating cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Cab_Review/courteousness
# Creating cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Cab_Review/courteousness
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  RECEIVESACTION
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  DONETO
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  HASPREREQUISITE
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  DESIREDBY
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  HASSUBEVENT
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  DESIRES
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  DESIRECAUSEDBY
# relation:  DESIRECAUSEDBY
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  CAPABLEOF
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  CREATES
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  DONEBY
# relation:  RELATEDTO
# relation:  RELATEDTO
# Creating cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Cab_Review/accommodation
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# Creating cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Cab_Review/peace-of-mind
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# Creating cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Cab_Review/edit
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# Creating cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Cab_Review/reputation
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# making copy of ../output/Cab_Review.json to ../output/savedStates/state_2023-03-11_13-53-00-542738.json
# self.stack: ['state_2023-03-11_13-53-00-542738.json']
# Refresh suggestion path:  [{'topic': 'Cab Review', 'relation': ''}]
# Refresh suggestion existing_children:  []
# Getting node path for:  d3703fa5-93b6-4722-835e-008fdfa6b73b
# relation: