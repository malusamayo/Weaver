# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from knowtest.server.Capability import Capability

# %%
c = Capability()
# Out:
# ../output/hate_speech
# Path:  ../output OS Path:  /Users/rishabhrustogi/Desktop/knowtest/notebooks
# Initializing wordnet
# Cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/hate_speech
# stateSaveDirectory: ../output/savedStates/
# maxStates: 100
# Setting root node:  Hate speech
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  CAUSES
# relation:  CAUSES
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  CAUSES
# relation:  CAUSES
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  CAUSES
# relation:  CAUSES
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  HASAGENT
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  HASAGENT
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  HASAGENT
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  HASPATIENT
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  HASPATIENT
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  HASPATIENT
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  PARTOF
# relation:  PARTOF
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  PARTOF
# relation:  PARTOF
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  PARTOF
# relation:  PARTOF
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  TYPESOF
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  TYPESOF
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  TYPESOF
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  ATLOCATION
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  has description
# relation:  CAUSES
# relation:  CAUSES
# relation:  used for
# relation:  CAUSES
# relation:  CAUSES
# relation:  TYPESOF
# relation:  CAUSES
# relation:  CAUSES
# relation:  obstructed by
# relation:  CAUSES
# relation:  CAUSES
# relation:  obstructed by
# relation:  CAUSES
# relation:  CAUSES
# relation:  has part
# relation:  CAUSES
# relation:  CAUSES
# relation:  done via
# relation:  CAUSES
# relation:  CAUSES
# relation:  done via
# relation:  CAUSES
# relation:  CAUSES
# relation:  TYPESOF
# relation:  CAUSES
# relation:  CAUSES
# relation:  located near
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  CAUSES
# relation:  HASAGENT
# relation:  HASAGENT
# relation:  HASAGENT
# relation:  HASPATIENT
# relation:  HASPATIENT
# relation:  DONEBY
# relation:  DONEBY
# relation:  HASPATIENT
# relation:  DONEBY
# relation:  DONEBY
# relation:  HASPATIENT
# relation:  DONEBY
# relation:  DONEBY
# relation:  HASPATIENT
# relation:  DONEBY
# relation:  DONEBY
# relation:  HASPATIENT
# relation:  DONEBY
# relation:  DONEBY
# relation:  HASPATIENT
# relation:  DONEBY
# relation:  DONEBY
# relation:  HASPATIENT
# relation:  DONEBY
# relation:  DONEBY
# relation:  HASPATIENT
# relation:  DONEBY
# relation:  DONEBY
# relation:  HASPATIENT
# relation:  DONEBY
# relation:  DONEBY
# relation:  HASPATIENT
# relation:  HASPATIENT
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  HASPROPERTY
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  LOCATEDNEAR
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MANNEROF
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  MOTIVATEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  OBSTRUCTEDBY
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  PARTOF
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  RELATEDTO
# relation:  TYPESOF
# relation:  TYPESOF
# relation:  TYPESOF
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# relation:  USEDFOR
# Starting server on port:  3001

# %%
c.change_topic("Samsung S23 Ultra")
# Out:
# ../output/Samsung_S23_Ultra
# Path:  ../output OS Path:  /Users/rishabhrustogi/Desktop/knowtest/notebooks
# Initializing wordnet
# Cache directory: /Users/rishabhrustogi/Desktop/knowtest/query_cache/Samsung_S23_Ultra
# stateSaveDirectory: ../output/savedStates/
# maxStates: 100
# Setting root node:  Samsung S23 Ultra
# relation:  has subevent
# relation:  has subevent
# relation:  has part
# relation:  has subevent
# relation:  desire caused by
# relation:  has subevent
# relation:  used for
# relation:  has subevent
# relation:  has subtype
# relation:  has subevent
# relation:  happens after
# relation:  has subevent
# relation:  has description
# relation:  has subevent
# relation:  has part
# relation:  has subevent
# relation:  has subevent
# relation:  has subevent
# relation:  has subevent
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  made of
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  done by
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  creates
# relation:  creates
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  desires
# relation:  desires
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  happens after
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  creates
# relation:  creates
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  desire caused by
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  happens after
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  happens after
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  happens after
# relation:  has subevent
# relation:  motivated by
# relation:  has subevent
# relation:  causes
# relation:  causes
# relation:  has subevent
# relation:  related to
# relation:  has subevent
# relation:  receives action
# relation:  has subevent
# relation:  has subevent
# relation:  has subevent
# relation:  used for
# relation:  has subevent
# relation:  has symbol
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  has subevent
# relation:  desires
# relation:  desires
# relation:  capable of
# relation:  has symbol
# relation:  has description
# relation:  done via
# relation:  done via
# relation:  made of
# relation:  happens after
# making copy of ../output/Samsung_S23_Ultra.json to ../output/savedStates/state_2023-03-13_12-29-28-450284.json
# self.stack: ['state_2023-03-13_12-29-28-450284.json']
# making copy of ../output/Samsung_S23_Ultra.json to ../output/savedStates/state_2023-03-13_13-11-08-392952.json
# self.stack: ['state_2023-03-13_12-29-28-450284.json', 'state_2023-03-13_13-11-08-392952.json']
# making copy of ../output/Samsung_S23_Ultra.json to ../output/savedStates/state_2023-03-13_14-49-30-861118.json
# self.stack: ['state_2023-03-13_12-29-28-450284.json', 'state_2023-03-13_13-11-08-392952.json', 'state_2023-03-13_14-49-30-861118.json']
# making copy of ../output/Samsung_S23_Ultra.json to ../output/savedStates/state_2023-03-13_14-49-31-938371.json
# self.stack: ['state_2023-03-13_12-29-28-450284.json', 'state_2023-03-13_13-11-08-392952.json', 'state_2023-03-13_14-49-30-861118.json', 'state_2023-03-13_14-49-31-938371.json']

# %% [markdown]
# |      Topics and Relations      |   |             Tooltip            |
# |:------------------------------:|:-:|:------------------------------:|
# |      <img src="data:image/png;base64,..." alt="Image" width="20" height="17"> Unhighlighted Topic     |   |       <img src="data:image/png;base64,..." alt="Image" width="18" height="19"> Highlight a Topic      |
# |       <img src="data:image/png;base64,..." alt="Image" width="19" height="18"> Highlighted Topic      |   |      <img src="data:image/png;base64,..." alt="Image" width="19" height="16"> Unhighlight a Topic     |
# |        <img src="data:image/png;base64,..." alt="Image" width="16" height="17"> Expanded topic        |   |      <img src="data:image/png;base64,..." alt="Image" width="17" height="20"> Refresh Suggestions     |
# |           <img src="data:image/png;base64,..." alt="Image" width="65" height="25"> Relation           |   | <img src="data:image/png;base64,..." alt="Image" width="18" height="20"> Edit Topic Name and Relation |
# | <img src="data:image/png;base64,..." alt="Image" width="140" height="22"> Relation and Topic wrt Parent |   |   <img src="data:image/png;base64,..." alt="Image" width="23" height="21"> Create new Topic Manually  |
# |      <img src="data:image/png;base64,..." alt="Image" width="108" height="46"> Filter by Relation      |   |        <img src="data:image/png;base64,..." alt="Image" width="16" height="17"> Delete a Topic        |

# %%
c.get_html_file()

# %%
c.get_js_file()

# %%
c.get_css_file()
